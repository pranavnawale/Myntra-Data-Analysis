# %% [markdown]
#    # Myntra Data Analysis
# ![unnamed.jpg](attachment:unnamed.jpg)

# %%
# install the dependencies
import pandas as pd
import numpy as np
import seaborn as sns 
from matplotlib import pyplot as plt

# %%
myntra=pd.read_csv("C:\\Users\\Pranav\\Desktop\\DATA SCIENCE DATA\\CVC file\\myntra_dataset.csv")
myntra.head()
# Out:
#                      product_name      brand_name  rating  rating_count  \
# 0   Croc Textured Two Fold Wallet     Lino Perros     0.0             0
# 1             Men Striped Sliders  Mast & Harbour     4.0            76
# 2            Printed A-line Kurta            Biba     4.3            66
# 3    Girls Floral Printed T-shirt        Anthrilo     0.0             0
# 4  Women Printed Kurta with Skirt    FASHION DWAR     0.0             0
#
#    marked_price  discounted_price                      sizes  \
# 0          1295               828                    Onesize
# 1          1299               584  UK6,UK7,UK8,UK9,UK10,UK11
# 2          1999              1599           S,M,L,XL,XXL,3XL
# 3           599               539            7-8Y,8-9Y,9-10Y
# 4          2899              2899                   S,M,L,XL
#
#                                         product_link  \
# 0  wallets/lino-perros/lino-perros-women-peach-co...
# 1  flip-flops/mast--harbour/mast--harbour-men-nav...
# ...

# %%
# shape of dataset
myntra.shape
# Out:
# (168029, 13)

# %%
# information about dataset
myntra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168029 entries, 0 to 168028
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   product_name      168029 non-null  object
#  1   brand_name        168029 non-null  object
#  2   rating            168029 non-null  float64
#  3   rating_count      168029 non-null  int64
#  4   marked_price      168029 non-null  int64
#  5   discounted_price  168029 non-null  int64
#  6   sizes             168029 non-null  object
#  7   product_link      168029 non-null  object
#  8   img_link          168029 non-null  object
#  9   product_tag       168029 non-null  object
#  10  brand_tag         168029 non-null  object
#  11  discount_amount   168029 non-null  int64
#  12  discount_percent  168029 non-null  int64
# dtypes: float64(1), int64(5), object(7)
# memory usage: 16.7+ MB

# %%
# Describe of dataset
myntra.describe()
# Out:
#               rating   rating_count  marked_price  discounted_price  \
# count  168029.000000  168029.000000  168029.00000     168029.000000
# mean        2.264556     114.668658    2509.07457       1515.168757
# std         2.101402     800.207065    2402.10918       1800.460291
# min         0.000000       0.000000      50.00000         49.000000
# 25%         0.000000       0.000000    1295.00000        674.000000
# 50%         3.500000       5.000000    1998.00000        999.000000
# 75%         4.300000      31.000000    2999.00000       1739.000000
# max         5.000000   55900.000000  113999.00000      45900.000000
#
#        discount_amount  discount_percent
# count    168029.000000     168029.000000
# mean        993.905814         37.251909
# std        1236.606569         24.638975
# min           0.000000          0.000000
# 25%         202.000000         15.000000
# 50%         702.000000         40.000000
# 75%        1319.000000         59.000000
# ...

# %%
# find ot null value in dataset
myntra.isnull().sum()
# Out:
# product_name        0
# brand_name          0
# rating              0
# rating_count        0
# marked_price        0
# discounted_price    0
# sizes               0
# product_link        0
# img_link            0
# product_tag         0
# brand_tag           0
# discount_amount     0
# discount_percent    0
# dtype: int64

# %%
# index of dataset
myntra.index
# Out:
# RangeIndex(start=0, stop=168029, step=1)

# %%
# columns in dataset
myntra.columns
# Out:
# Index(['product_name', 'brand_name', 'rating', 'rating_count', 'marked_price',
#        'discounted_price', 'sizes', 'product_link', 'img_link', 'product_tag',
#        'brand_tag', 'discount_amount', 'discount_percent'],
#       dtype='object')

# %%
 # Dtypes of dataset
myntra.dtypes
# Out:
# product_name         object
# brand_name           object
# rating              float64
# rating_count          int64
# marked_price          int64
# discounted_price      int64
# sizes                object
# product_link         object
# img_link             object
# product_tag          object
# brand_tag            object
# discount_amount       int64
# discount_percent      int64
# dtype: object

# %%
# Delate Unwanted column
del myntra['product_link']
del myntra['img_link']
myntra.head()
# Out:
#                      product_name      brand_name  rating  rating_count  \
# 0   Croc Textured Two Fold Wallet     Lino Perros     0.0             0
# 1             Men Striped Sliders  Mast & Harbour     4.0            76
# 2            Printed A-line Kurta            Biba     4.3            66
# 3    Girls Floral Printed T-shirt        Anthrilo     0.0             0
# 4  Women Printed Kurta with Skirt    FASHION DWAR     0.0             0
#
#    marked_price  discounted_price                      sizes product_tag  \
# 0          1295               828                    Onesize     wallets
# 1          1299               584  UK6,UK7,UK8,UK9,UK10,UK11  flip-flops
# 2          1999              1599           S,M,L,XL,XXL,3XL      kurtas
# 3           599               539            7-8Y,8-9Y,9-10Y     tshirts
# 4          2899              2899                   S,M,L,XL  kurta-sets
#
#        brand_tag  discount_amount  discount_percent
# ...

# %% [markdown]
# ### Data Analysis-Numeric Column
# #### Average rating of a product(non zero)

# %%
myntra['rating'].mean()
# Out:
# 2.2645561182889926

# %%
rat=0
c=0

for i in myntra['rating']:
    if(i !=0.0):
        rat +=i
        c+=1

        print(round(int(rat)/c,2))
# Out:
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.11
# 4.1
# 4.18
# 4.17
# 4.15
# 4.21
# 4.2
# 4.25
# 4.24
# 4.22
# 4.26
# 4.25
# 4.24
# 4.23
# 4.22
# 4.25
# 4.2
# 4.23
# 4.22
# 4.18
# 4.21
# 4.1
# 4.1
# 4.09
# 4.09
# 4.09
# 4.09
# 4.11
# 4.11
# 4.11
# 4.1
# 4.1
# 4.1
# 4.1
# 4.02
# 4.02
# 4.02
# 4.02
# 4.02
# 4.02
# 4.04
# 4.04
# 4.06
# 4.06
# 4.06
# 4.06
# 4.07
# 4.05
# 4.04
# 4.05
# 4.05
# 4.05
# 4.05
# 4.05
# 4.05
# 4.05
# 4.05
# 4.05
# 4.04
# 4.06
# 4.06
# 4.06
# 4.07
# 4.07
# 4.07
# 4.07
# 4.07
# 4.08
# 4.08
# 4.09
# 4.09
# 4.09
# 4.1
# 4.09
# 4.1
# 4.1
# 4.11
# 4.09
# 4.1
# 4.1
# 4.1
# 4.11
# 4.11
# 4.11
# 4.1
# 4.11
# 4.12
# 4.11
# 4.11
# 4.12
# 4.12
# 4.12
# 4.12
# 4.13
# 4.11
# 4.11
# 4.1
# 4.1
# 4.11
# 4.1
# 4.1
# 4.1
# 4.1
# 4.1
# 4.1
# 4.11
# 4.1
# 4.11
# 4.11
# 4.11
# 4.11
# 4.12
# 4.12
# 4.11
# 4.11
# 4.11
# 4.12
# 4.12
# 4.12
# 4.12
# 4.12
# 4.12
# 4.12
# 4.12
# 4.12
# 4.13
# 4.12
# 4.12
# 4.12
# 4.12
# 4.12
# 4.11
# 4.12
# 4.12
# 4.12
# 4.12
# 4.12
# 4.12
# 4.12
# ...

# %%
int(rat)
# Out:
# 380511

# %%
c
# Out:
# 91349

# %% [markdown]
# ### Most expensive product (Marked price)

# %%
myntra['marked_price'].max()
# Out:
# 113999

# %%
myntra[myntra['marked_price']==113999]
# Out:
#                  product_name   brand_name  rating  rating_count  \
# 27039  Lord Krishna Showpiece  eCraftIndia     0.0             0
#
#        marked_price  discounted_price    sizes product_tag    brand_tag  \
# 27039        113999             45599  Onesize  showpieces  ecraftindia
#
#        discount_amount  discount_percent
# 27039            68400                60

# %% [markdown]
# ### Most Discount product (Marked price)

# %%
myntra['discounted_price'].max()
# Out:
# 45900

# %%
myntra[myntra['discounted_price']==myntra['discounted_price'].max()]
# Out:
#                      product_name brand_name  rating  rating_count  \
# 29599  Men Automatic Motion Watch  D1 Milano     0.0             0
#
#        marked_price  discounted_price    sizes product_tag  brand_tag  \
# 29599         51000             45900  Onesize     watches  d1-milano
#
#        discount_amount  discount_percent
# 29599             5100                10

# %% [markdown]
# ### Most Discount product (Persentage)

# %%
myntra[myntra['discount_percent']==myntra['discount_percent'].max()]
# Out:
#                       product_name brand_name  rating  rating_count  \
# 132294  Dharmavaram Art Silk Saree  MS RETAIL     0.0             0
#
#         marked_price  discounted_price    sizes product_tag  brand_tag  \
# 132294         13650              1228  Onesize      sarees  ms-retail
#
#         discount_amount  discount_percent
# 132294            12422                91

# %% [markdown]
# ### Most Discount product (Amount)

# %%
myntra[myntra['discount_amount']==myntra['discount_amount'].max()]
# Out:
#                  product_name   brand_name  rating  rating_count  \
# 27039  Lord Krishna Showpiece  eCraftIndia     0.0             0
#
#        marked_price  discounted_price    sizes product_tag    brand_tag  \
# 27039        113999             45599  Onesize  showpieces  ecraftindia
#
#        discount_amount  discount_percent
# 27039            68400                60

# %% [markdown]
# ### Shortlisting products based on specific filters

# %%
myntra_product=myntra[myntra['discounted_price']>2000]
myntra_product=myntra_product[myntra_product['discounted_price']<3000]
myntra_product=myntra_product[myntra_product['product_tag']=='handbags']


myntra_product.sort_values(by='discounted_price',ascending=False).head(10)
# Out:
#                           product_name   brand_name  rating  rating_count  \
# 111104      Solid Structured Sling Bag      Caprese     0.0             0
# 141856        Women Solid Handheld Bag      Caprese     4.1           132
# 42500        Women Structured Hobo Bag      Caprese     0.0             0
# 132102             Structured Hobo Bag      Caprese     0.0             0
# 22429   Printed Structured HandheldBag  Allen Solly     0.0             0
# 22918    Solid Structured Shoulder Bag      Caprese     0.0             0
# 55929          Structured Handheld Bag      Caprese     0.0             0
# 78451              Structured Hobo Bag      Caprese     5.0             8
# 135230               Net Bag and Pouch          H&M     0.0             0
# 162471           Textured Handheld Bag     MIRAGGIO     4.5            64
#
#         marked_price  discounted_price    sizes product_tag    brand_tag  \
# 111104          4999              2999  Onesize    handbags      caprese
# ...

# %% [markdown]
# ### Finding All the brand Name

# %%
myntra['brand_name'].unique()
# Out:
# array(['Lino Perros', 'Mast & Harbour', 'Biba', ..., 'Myra', 'StylPro',
#        'LIL PITAARA'], dtype=object)

# %%
for brand_name in myntra['brand_name'].unique():
    
    c=0
    for i in myntra['brand_name']:
        if (i=='brand_name'):
            c+=1
            
    print(brand_name,c)
# Out:
# Lino Perros 0
# Mast & Harbour 0
# Biba 0
# Anthrilo 0
# FASHION DWAR 0
# Vishudh 0
# Tokyo Talkies 0
# Woakers 0
# Roadster 0
# H&M 0
# Mystere Paris 0
# Accessorize 0
# Jompers 0
# FOOTONS 0
# ID 0
# Zaveri Pearls 0
# Toy Balloon kids 0
# Greenfibre 0
# ASIAN 0
# HIGHLANDER 0
# U.S. Polo Assn. 0
# HRX by Hrithik Roshan 0
# ZALORA BASICS 0
# BEAUCODE BIOCARE 0
# MANGO 0
# INVICTUS 0
# Kipsta By Decathlon 0
# Hush Puppies 0
# Nejo 0
# Rubeezz 0
# GUESS 0
# Tikhi Imli 0
# Soch 0
# HERE&NOW 0
# Anouk 0
# Levis 0
# Stylo Bug 0
# ONLY 0
# Flying Machine 0
# Park Avenue 0
# Sztori 0
# Weinbrenner 0
# Colorbar 0
# IVOC 0
# Harvard 0
# Blackberrys 0
# Divena 0
# AMERICAN EAGLE OUTFITTERS 0
# WISSTLER 0
# V-Mart 0
# DRAPE IN VOGUE 0
# Aaruvi Ruchi Verma 0
# Clarks 0
# WROGN 0
# iki chic 0
# MANGO MAN 0
# Puma 0
# Lavie 0
# abof 0
# all about you 0
# Meeranshi 0
# Suta 0
# La Aimee 0
# Friskers 0
# mirari 0
# Wrangler 0
# Kastner 0
# one8 x PUMA 0
# Amante 0
# Pacific Gold 0
# Bata 0
# ...

# %% [markdown]
# ### Finding the Brand with most number of product

# %%
for brand_name in myntra['brand_name'].unique():
    
    c=0
    for i in myntra['brand_name']:
        if (i=='brand_name'):
            c+=1
            
            
    myntra.append([brand_name,c]) 
myntra=pd.DataFrame(myntra,columns=['brand_name','product_name'])    
myntra.head()
# Out:
# C:\Users\Pranav\AppData\Local\Temp\ipykernel_16892\2146042503.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   myntra.append([brand_name,c])
#        brand_name                    product_name
# 0     Lino Perros   Croc Textured Two Fold Wallet
# 1  Mast & Harbour             Men Striped Sliders
# 2            Biba            Printed A-line Kurta
# 3        Anthrilo    Girls Floral Printed T-shirt
# 4    FASHION DWAR  Women Printed Kurta with Skirt
